# %%
import pandas as pd
import re

# %%
data = pd.read_csv('dataset.csv')
#empty_value = data.isnull().sum()
clean_data = data.dropna(how='any')

clean_data.to_csv('dataset.csv')

# %%
data = pd.read_csv('dataset.csv')
print("Original data shape:", data.shape)

clean_data = data.dropna(how='any')
print("Cleaned data shape:", clean_data.shape)

new_data = clean_data.drop_duplicates()
# Out:
# Original data shape: (433688, 9)
# Cleaned data shape: (433688, 9)
#         Unnamed: 0 InvoiceNo StockCode                           Description  \
# 0                0    536365    85123A    WHITE HANGING HEART T-LIGHT HOLDER
# 1                1    536365     71053                   WHITE METAL LANTERN
# 2                2    536365  ö84406B^        CREAM CUPID HEARTS COAT HANGER
# 3                3    536365    84029G  $KNITTED UNION FLAG HOT WATER BOTTLE
# 4                4    536365    84029E       $RED WOOLLY HOTTIE WHITE HEART.
# ...            ...       ...       ...                                   ...
# 433683      541904   581587ä   ö22613^           PACK OF 20 SPACEBOY NAPKINS
# 433684      541905    581587   ö22899^          CHILDREN'S APRON DOLLY GIRL
# 433685      541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL
# 433686      541907   581587ä     23255       CHILDRENS CUTLERY CIRCUS PARADE
# ...

# %%
# clean_data['InvoiceDate'] = clean_data['InvoiceDate'].str.replace(r'\s+\d{2}:\d{2}:\d{2}', '', regex=True)
# clean_data['InvoiceDate'] =clean_data['InvoiceDate'].str.replace(r'[-]', '', regex=True)
# clean_data['Quantity'] = clean_data['Quantity'].str.replace( r'[@]', '', regex=True)
# clean_data['Quantity'] = pd.to_numeric(clean_data['Quantity'], errors='coerce')
# clean_data['InvoiceDate'] = pd.to_numeric(clean_data['InvoiceDate'], errors='coerce')
clean_data = pd.read_csv('dataset.csv')
head = clean_data.head(10)
head.plot.bar(x='InvoiceDate', y='Quantity')
# Out:
# <Axes: xlabel='InvoiceDate'>
